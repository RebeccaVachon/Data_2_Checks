# %%
import pandas as pd
import numpy as np

data = pd.read_csv('https://www.irs.gov/pub/irs-soi/eo_ky.csv')

# displaying the top 10 rows of the newly created comparsion_df DataFrame to ensure it was loaded correctly
data.head(10)
# Out:
#         EIN                                               NAME  \
# 0  10356732                         CARRIAGE MUSEUM OF AMERICA
# 1  10551398                     HIGHLANDS BAND ASSOCIATION INC
# 2  10554843            JEFFERSON COUNTY SEARCH DOG ASSOCIATION
# 3  10557144                                  AUGUSTA ART GUILD
# 4  10557631                    KENTUCKY ALPACA ASSOCIATION INC
# 5  10560598               CHILD DEVELOPMENT CENTER CORPORATION
# 6  10563104  FRIENDSHIP AND COMMUNITY EXPERIENCING SUCCESS INC
# 7  10582200                          KENTUCKY PAINT HORSE CLUB
# 8  10597359                      SPIRIT OF JOY LIFE MINISTRIES
# 9  10600655            CHRIST CHURCH OF PRAYER AND DELIVERANCE
#
#                  ICO                STREET         CITY STATE         ZIP  \
# 0                NaN  4075 IRON WORKS PKWY    LEXINGTON    KY  40511-8483
# 1     % STANLEY ROSS          PO BOX 75029  FORT THOMAS    KY  41075-0029
# ...

# %%
# dropping unneccessary columns
data = data.drop(['ICO', 'ORGANIZATION', "SUBSECTION", "CLASSIFICATION", "PF_FILING_REQ_CD","FILING_REQ_CD", "ASSET_CD", "INCOME_CD"], axis=1)


#changing the Ruling Date column to a date
data['RULING'] = pd.to_datetime(data['RULING'], format='%Y%m', errors='coerce')

# changing NAN values in three columns to zeros
Columns = ["ASSET_AMT", "INCOME_AMT", "REVENUE_AMT"]
for x in Columns:
    data[x] = data[x].fillna(0)

# displaying the top 10 rows again to make sure data has been cleaned correctly
data.head(10)
# Out:
#         EIN                                               NAME  \
# 0  10356732                         CARRIAGE MUSEUM OF AMERICA
# 1  10551398                     HIGHLANDS BAND ASSOCIATION INC
# 2  10554843            JEFFERSON COUNTY SEARCH DOG ASSOCIATION
# 3  10557144                                  AUGUSTA ART GUILD
# 4  10557631                    KENTUCKY ALPACA ASSOCIATION INC
# 5  10560598               CHILD DEVELOPMENT CENTER CORPORATION
# 6  10563104  FRIENDSHIP AND COMMUNITY EXPERIENCING SUCCESS INC
# 7  10582200                          KENTUCKY PAINT HORSE CLUB
# 8  10597359                      SPIRIT OF JOY LIFE MINISTRIES
# 9  10600655            CHRIST CHURCH OF PRAYER AND DELIVERANCE
#
#                  STREET         CITY STATE         ZIP  GROUP  AFFILIATION  \
# 0  4075 IRON WORKS PKWY    LEXINGTON    KY  40511-8483      0            3
# 1          PO BOX 75029  FORT THOMAS    KY  41075-0029      0            3
# ...
